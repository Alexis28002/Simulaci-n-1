# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexis28002/Simulaci-n-1/blob/main/Programa%201%20(generador%20aleatorio).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def f(x,a,c,m):
  return (a*x+c)%m
a=37
c=18
m=43
x=11
l=[]
while x not in l:
  l.append(x)
  x=f(x,a,c,m)
print(l)
# Out:
# [11, 38, 5, 31, 4, 37]
